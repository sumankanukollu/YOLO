# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

import sys,os
from pathlib import Path


homepath = Path('/content/drive/My Drive/pytorch_Framework_suman/')
sys.path.append(str(homepath))

sys.path.append(os.path.join(homepath,'lib'))
sys.path.append(os.path.join(homepath,'YOLO'))

print(sys.path)

# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# ['', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/My Drive/pytorch_Framework_suman', '/content/drive/My Drive/pytorch_Framework_suman/lib', '/content/drive/My Drive/pytorch_Framework_suman/YOLO']
# drive  sample_data

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
cd /content/drive/My Drive/pytorch_Framework_suman/YoloV3
# Out:
# /content/drive/My Drive/pytorch_Framework_suman/YoloV3

# %%
# !pwd
# !ls
# Out:
# /content/drive/My Drive/pytorch_Framework_suman/YoloV3
#  annotation_tool   README.md			       Tom_Test_BB_1500
#  cfg		   results.json			       Tom_Yolov3_TestVedio.mp4
#  data		   results.png			       train.py
#  detect.py	   runs				      'ubdivisions=1'
#  models.py	   test.py			       utils
#  out_out	   test_yolov3_tomNdJerry_Diwali.mp4   vim.exe.stackdump
#  output		   ting				       weights
#  __pycache__	   Tom_Test_BB

# %%
#!python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !python detect.py --conf-thres 0.1 --output Tom_Test_BB_1500 --source test_yolov3_tomNdJerry_Diwali.mp4
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='Tom_Test_BB_1500', save_txt=False, source='test_yolov3_tomNdJerry_Diwali.mp4', view_img=False, weights='weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/891) test_yolov3_tomNdJerry_Diwali.mp4: 320x512 1 toms, Done. (0.017s)
# video 1/1 (2/891) test_yolov3_tomNdJerry_Diwali.mp4: 320x512 1 toms, Done. (0.016s)
# video 1/1 (3/891) test_yolov3_tomNdJerry_Diwali.mp4: 320x512 1 toms, Done. (0.016s)
# video 1/1 (4/891) test_yolov3_tomNdJerry_Diwali.mp4: 320x512 1 toms, Done. (0.016s)
# video 1/1 (5/891) test_yolov3_tomNdJerry_Diwali.mp4: 320x512 1 toms, Done. (0.016s)
# ...

# %%
#Image(filename='Tom_Test_BB_1500/frame_0000.jpg', width=600)

# %%
#Image(filename='Tom_Test_BB_1500/frame_0012.jpg', width=600)

# %%
#Image(filename='Tom_Test_BB_1500/frame_0054.jpg', width=600)

# %%
# !cd Tom_Test_BB_1500/

# %%
# !ls
# Out:
#  annotation_tool   README.md			       Tom_Test_BB_1500
#  cfg		   results.json			       Tom_Yolov3_TestVedio.mp4
#  data		   results.png			       train.py
#  detect.py	   runs				      'ubdivisions=1'
#  models.py	   test.py			       utils
#  out_out	   test_yolov3_tomNdJerry_Diwali.mp4   vim.exe.stackdump
#  output		   ting				       weights
#  __pycache__	   Tom_Test_BB
